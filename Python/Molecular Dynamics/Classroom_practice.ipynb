# %% [markdown]
# <a href="https://colab.research.google.com/github/alifele/Simulation-Methods/blob/master/Python/Molecular%20Dynamics/Classroom_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Note That this file is only commpatible with jupyter notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

ax.set_xlim(( 0,L))
ax.set_ylim((0,L))
N=20
L = 10
pos = np.random.random((N,2))*L
vel = np.random.random((N,2))*2 - 1
data = np.hstack((pos,vel))
line, = ax.plot([],[],'8', lw=2)

# %%
def position_update():
    data[:,0] += 0.2*data[:,2]
    data[:,1] += 0.2*data[:,3]

# %%
def wallbounce():
    data[:,2][data[:,0]>= L] *= -1
    data[:,2][data[:,0]<= 0] *= -1
    data[:,3][data[:,1]>=L] *= -1
    data[:,3][data[:,1]<=0] *= -1

# %%
# initialization function: plot the background of each frame
def init():
    line.set_data([],[])
    return (line,)

# %%
# animation function. This is called sequentially

def animate(i):
   
    #x = np.linspace(0, 2, 1000)
    #y = np.sin(2 * np.pi * (x - 0.01 * i))
    position_update()
    wallbounce()
    line.set_data(data[:,0] ,data[:,1])
    return (line,)

# %%
# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=100, blit=True)

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
arr = np.random.random(10)*10

# %%
arr
# Out:
# array([7.34091494, 1.05119963, 0.76655508, 9.28535016, 6.09118015,
#        5.66411848, 2.91990287, 7.22209616, 7.04564168, 2.09181315])

# %%
arr[arr>5]*=-1

# %%
arr
# Out:
# array([-7.34091494,  1.05119963,  0.76655508, -9.28535016, -6.09118015,
#        -5.66411848,  2.91990287, -7.22209616, -7.04564168,  2.09181315])
